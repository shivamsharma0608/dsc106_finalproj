# %% [markdown]
# # Proposal Viz 1 — The Game Over Time (Luis)
#
# Static mock-up for Visual 1 in the team proposal (final: D3 animated line chart + metric dropdown).

# %%
# %run ../scripts/generate_viz_01.py

# %%
from IPython.display import Image, display
display(Image(filename="../visuals/viz_01_game_over_time.png"))
